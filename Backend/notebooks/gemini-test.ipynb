# %%
import handy_functions as hf
from google import genai
from google.genai import types
# Out:
# 2025-03-02 14:55:28.337 | DEBUG    | wykop.wykop_api:authenticate:42 - Authenticated successfully.

# %% [markdown]
# Inicjalizacja klienta openAi

# %%
client = genai.Client(api_key="AIzaSyBVLiobdrNnyJT7zMN1HyLYa7bU52owuik")

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Explain how AI works",
)

# %%
response
# Out:
# GenerateContentResponse(candidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, inline_data=None, text='Okay, let\'s break down how AI works. It\'s a complex field, but I\'ll try to explain it in a clear and understandable way, focusing on the core concepts.\n\n**What is AI?**\n\nAt its most fundamental level, AI (Artificial Intelligence) is about creating computer systems that can perform tasks that typically require human intelligence. These tasks might include:\n\n*   **Learning:** Acquiring information and rules for using the information\n*   **Reasoning:** Using rules to reach conclusions (either exact or approximate)\n*   **Problem-solving:** Finding solutions to complex issues\n*   **Perception:** Understanding sensory inputs (e.g., vision, sound, text)\n*   **Language Understanding:** Comprehending and generating human language\n\n**Key Concepts and Techniques:**\n\n1.  **Machine Learning (ML):**  The cornerstone of modern AI. Instead of explicitly programming every rule, ML allows systems to learn from data. Think of it as training a dog with treats.\n\n    *   **How it works:** You feed the machine learning algorithm a large amount of data (training data). The algorithm looks for patterns in the data and adjusts its internal parameters (think of these as connections in a brain) to make accurate predictions or decisions.  The more data it sees, the better it becomes.\n\n    *   **Types of Machine Learning:**\n\n        *   **Supervised Learning:**  You give the algorithm labeled data (e.g., pictures of cats labeled "cat" and pictures of dogs labeled "dog"). The algorithm learns to associate features in the pictures with the correct label.  It\'s like teaching a child by showing them examples and telling them what they are.\n        *   **Unsupervised Learning:** You give the algorithm unlabeled data (e.g., a bunch of customer data without any pre-defined categories).  The algorithm tries to find patterns and structures in the data, like grouping customers into segments based on their purchasing behavior.  It\'s like letting a child explore a room and figure things out on their own.\n        *   **Reinforcement Learning:** The algorithm learns by trial and error, receiving rewards or penalties for its actions in a certain environment. Think of training a robot to walk by rewarding it for taking steps in the right direction.  It\'s like playing a game and learning from your mistakes to improve your score.\n\n2.  **Deep Learning (DL):** A subfield of machine learning that uses artificial neural networks with multiple layers (hence "deep").  It\'s particularly good at handling complex patterns in data like images, audio, and text.\n\n    *   **How it works:** Inspired by the structure of the human brain, neural networks consist of interconnected nodes (neurons) organized in layers. Each connection has a weight associated with it. The network learns by adjusting these weights to minimize errors in its predictions.  The more layers, the more complex the patterns the network can learn.\n\n    *   **Why it\'s powerful:** Deep learning has achieved remarkable results in areas like image recognition, natural language processing, and speech recognition.  This is due to its ability to automatically learn hierarchical representations of data.\n\n3.  **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language.\n\n    *   **How it works:**  NLP involves a range of techniques, including:\n        *   **Text analysis:** Breaking down text into its components (words, sentences, etc.).\n        *   **Sentiment analysis:** Determining the emotional tone of text (positive, negative, neutral).\n        *   **Machine translation:** Translating text from one language to another.\n        *   **Language generation:** Creating new text that is grammatically ...

# %% [markdown]
# pobranie wpisów

# %%
wpisy = hf.get_posts_and_comments("sebcel", 1)
wpisy
# Out:
# 2025-03-02 14:55:41.082 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/tags/sebcel/stream?page=1&limit=25&sort=all&type=entry&multimedia=false'
# 2025-03-02 14:55:42.421 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80383803/comments?page=1&limit=25
# 2025-03-02 14:55:43.481 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80383569/comments?page=1&limit=25
# 2025-03-02 14:55:44.563 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80383443/comments?page=1&limit=25
# 2025-03-02 14:55:45.601 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80383311/comments?page=1&limit=25
# 2025-03-02 14:55:46.643 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80383289/comments?page=1&limit=25
# 2025-03-02 14:55:46.696 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80383289/comments?page=2&limit=25
# 2025-03-02 14:55:47.745 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80383209/comments?page=1&limit=25
# 2025-03-02 14:55:48.801 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80383127/comments?page=1&limit=25
# 2025-03-02 14:55:49.852 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80382817/comments?page=1&limit=25
# 2025-03-02 14:55:50.891 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80382275/comments?page=1&limit=25
# 2025-03-02 14:55:50.943 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80382275/comments?page=2&limit=25
# 2025-03-02 14:55:51.987 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80380505/comments?page=1&limit=25
# 2025-03-02 14:55:52.030 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80380505/comments?page=2&limit=25
# 2025-03-02 14:55:53.081 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80378643/comments?page=1&limit=25
# 2025-03-02 14:55:54.120 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80378309/comments?page=1&limit=25
# 2025-03-02 14:55:54.170 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80378309/comments?page=2&limit=25
# 2025-03-02 14:55:55.211 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80378149/comments?page=1&limit=25
# 2025-03-02 14:55:55.263 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80378149/comments?page=2&limit=25
# 2025-03-02 14:55:56.309 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80377639/comments?page=1&limit=25
# 2025-03-02 14:55:56.370 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80377639/comments?page=2&limit=25
# 2025-03-02 14:55:57.429 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80375023/comments?page=1&limit=25
# 2025-03-02 14:55:57.482 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80375023/comments?page=2&limit=25
# 2025-03-02 14:55:58.532 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80374691/comments?page=1&limit=25
# 2025-03-02 14:55:58.581 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80374691/comments?page=2&limit=25
# 2025-03-02 14:55:59.624 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80374321/comments?page=1&limit=25
# 2025-03-02 14:55:59.745 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80374321/comments?page=2&limit=25
# 2025-03-02 14:56:00.792 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80373267/comments?page=1&limit=25
# 2025-03-02 14:56:01.833 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80372507/comments?page=1&limit=25
# 2025-03-02 14:56:01.903 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80372507/comments?page=2&limit=25
# 2025-03-02 14:56:02.949 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80372161/comments?page=1&limit=25
# 2025-03-02 14:56:03.005 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80372161/comments?page=2&limit=25
# 2025-03-02 14:56:04.049 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80371953/comments?page=1&limit=25
# 2025-03-02 14:56:04.094 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80371953/comments?page=2&limit=25
# 2025-03-02 14:56:05.134 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80370919/comments?page=1&limit=25
# 2025-03-02 14:56:05.186 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80370919/comments?page=2&limit=25
# 2025-03-02 14:56:06.242 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80370663/comments?page=1&limit=25
# 2025-03-02 14:56:07.281 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80370381/comments?page=1&limit=25
# 2025-03-02 14:56:08.333 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80369799/comments?page=1&limit=25
# 2025-03-02 14:56:08.397 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80369799/comments?page=2&limit=25
# [[80383803,
#   'Technick20',
#   '#frajerzyzmlm #sebcel',
#   ['frajerzyzmlm', 'sebcel'],
#   '2025-03-02 14:03:50'],
#  [80383569,
#   'thority',
#   'To jak to w końcu było z eventem.\n#sebcel',
#   ['sebcel'],
#   '2025-03-02 13:45:31'],
#  [80383443,
#   'dawid-hopek',
#   '#sebcel nie ma przez weekend, bo na weekend Hans lepiej płaci',
#   ['sebcel'],
#   '2025-03-02 13:35:12'],
#  [80383311,
#   'Stebat',
#   'Jak najbardziej, dalej myślę że się nie da\n\n#sebcel #frajerzyzmlm',
#   ['sebcel', 'frajerzyzmlm'],
#   '2025-03-02 13:21:46'],
#  [80383289,
#   'Stebat',
#   '"Dlaczego Nixon pałą jest"\n\n#sebcel',
#   ['sebcel'],
#   '2025-03-02 13:19:56'],
#  [279952437,
#   'AgentGRU',
#   '@Stebat: dlaczego? Dlatego.',
#   [],
#   '2025-03-02 13:19:56'],
#  [80383209,
#   'mackbig',
#   'Tomek wyjazd integracyjny ma wartość. Ale......\n\nI teraz takie skupienie\n\nAle jak ty kupujesz bilet i na nie jedziesz. To masz kajdany..... Musisz z---------ć na mentora\n\n#sebcel',
#   ['sebcel'],
#   '2025-03-02 13:11:18'],
#  [80383127,
#   'kakaowy_chlebicek',
#   '#sebcel nie ma łoniaków',
#   ['sebcel'],
#   '2025-03-02 13:04:43'],
#  [80382817,
#   'bb89',
#   'Słowa nie idą za czynami, jak najbardzej \n\n#sebcel',
#   ['sebcel'],
#   '2025-03-02 12:37:40'],
#  [80382275,
#   'NaczelnyAgnostyk',
#   '#sebcel Dlaczego',
#   ['sebcel'],
#   '2025-03-02 11:56:02'],
#  [279946801,
#   'NaczelnyAgnostyk',
#   '@NaczelnyAgnostyk: Dlatego',
#   [],
#   '2025-03-02 11:56:02'],
#  [279947357,
#   'moet',
#   '@NaczelnyAgnostyk: że nie masz swoich celów, k---a',
#   [],
#   '2025-03-02 11:56:02'],
#  [279947377,
#   'entgegen',
#   '@NaczelnyAgnostyk: NO I KUUUUUMWA',
#   [],
#   '2025-03-02 11:56:02'],
#  [279948291, '006mika', '@entgegen: mazdaaA', [], '2025-03-02 11:56:02'],
#  [80380505,
#   'Usmiech_Niebios',
#   'Ludzie którzy czepiają się braku pojechania do budapesztu nie pamiętają dwóch rzeczy\n- metodyki contrawise\n- poprzedniego eventu gdzie sebe nie pojechał i udawał że tam był\nprzemyśl: to sobie.\n#sebcel',
#   ['sebcel'],
#   '2025-03-02 07:50:04'],
#  [279940777,
#   'bb89',
#   '@Usmiech_Niebios po drugie nigdzie nie powiedział że jedzie, a po pierwsze pozdrawiam huberta',
#   [],
#   '2025-03-02 07:50:04'],
#  [279940879,
#   'maz00rskie_mleko',
#   '@Usmiech_Niebios mmmm Barcelona, to byli czasy. Gmachu i spółka jeszcze nie wiedzieli co ich trafi.',
#   [],
#   '2025-03-02 07:50:04'],
#  [80378643,
#   'slabehaslo',
#   '#sebcel seba nigdy nie mówił że pojedzie, tylko jak ktoś pojedzie to żeby mówił że od seby, że niby kogoś przekonał\xa0XD',
#   ['sebcel'],
#   '2025-03-01 22:56:45'],
#  [80378309,
#   'DzikuDziczyzna',
#   '#sebcel \nSeba nie pojechał do Budapesztu\nSeba nie pojechał do Budapesztu\nSeba nie pojechał do Budapesztu',
#   ['sebcel'],
#   '2025-03-01 22:26:29'],
#  [279935221,
#   'Widur',
#   '@DzikuDziczyzna: Brydadzista z Rumunii nie zgodził się na urlop',
#   [],
#   '2025-03-01 22:26:29'],
#  [279936935,
#   '006mika',
#   '@DzikuDziczyzna: buty mu zamokły w szklarni i nie miał gdzie wysuszyć bo w baraku nie grzeją',
#   [],
#   '2025-03-01 22:26:29'],
#  [80378149,
#   'klefonafide',
#   'seba pojechał na event do Budapesztu, czy tylko p-------ł, że się da tam pojechać?\n\n#sebcel',
#   ['sebcel'],
#   '2025-03-01 22:12:31'],
#  [279931989,
#   'Jedwabnik43',
#   '@klefonafide Nie pojechał, jego mentor jak najbardziej pewnie kazał mu tylko promować ten event. Jakby tam byl to by n---------ł milion relacji dziennie z tego.',
#   [],
#   '2025-03-01 22:12:31'],
#  [279938683,
#   'AgentGRU',
#   '>seba pojechał na event do Budapesztu,\n\n@klefonafide: pojechał tak jak na maraton xD',
#   [],
#   '2025-03-01 22:12:31'],
#  [80377639,
#   'zdjecie_z_wenszem',
#   'kiedy #sebcel zakłada onlyfans jak najbardziej bambusy? #frajerzyzmlm',
#   ['sebcel', 'frajerzyzmlm'],
#   '2025-03-01 21:34:43'],
#  [279930429,
#   'slabehaslo',
#   '@zdjecie_z_wenszem: chyba onlybambus',
#   [],
#   '2025-03-01 21:34:43'],
#  [279931769,
#   'vulcanitu',
#   '@zdjecie_z_wenszem: ja wiem, że pragniecie wartości ale no uspokójcie się nieco ( ͡° ͜ʖ ͡°)',
#   [],
#   '2025-03-01 21:34:43'],
#  [279933153,
#   'paramedix',
#   '@zdjecie_z_wenszem: przegiąłeś…',
#   [],
#   '2025-03-01 21:34:43'],
#  [80375023,
#   'tasaku',
#   'duża wartość tutaj na rynek #sebcel #gmachcel #frajerzyzmlm',
#   ['sebcel', 'gmachcel', 'frajerzyzmlm'],
#   '2025-03-01 18:52:49'],
#  [279925495,
#   '006mika',
#   '@tasaku: jak tak tu na to patrzę to zrobił mi ...ekhh..mentalnego loda',
#   [],
#   '2025-03-01 18:52:49'],
#  [279940369,
#   'bb89',
#   '@tasaku akurat konieczne ustawienie stop lossa szybko wyczyściło wszystkich „trejderów” w ostatnim tygodniu ( ͡° ͜ʖ ͡°)',
#   [],
#   '2025-03-01 18:52:49'],
#  [80374691,
#   'podrywacz1',
#   '#sebcel #contrawise',
#   ['sebcel', 'contrawise'],
#   '2025-03-01 18:35:30'],
#  [279925567,
#   '006mika',
#   '@podrywacz1: bambus się nauczył od sebka i cwaniakuje',
#   [],
#   '2025-03-01 18:35:30'],
#  [80374321,
#   'BKZGlamrap',
#   'Pięknie #gmachcel się spłakał XDDD.\n\n#sebcel #frajerzyzmlm #bekazpodludzi',
#   ['gmachcel', 'sebcel', 'frajerzyzmlm', 'bekazpodludzi'],
#   '2025-03-01 18:17:38'],
#  [279922613,
#   'paramedix',
#   '@BKZGlamrap: "Dział prawny" - pakuj szczoteczkę i pastę do zębów, smutni panowie z płokułatuły już po Ciebie jadą ¯\\(ツ)/¯',
#   [],
#   '2025-03-01 18:17:38'],
#  [279922679,
#   'ShiroUmizake',
#   '@BKZGlamrap: dawaj channel, kolega chyba nie zna efektu streisand.( ͡° ͜ʖ ͡°)',
#   [],
#   '2025-03-01 18:17:38'],
#  [279922779,
#   'levzor',
#   '@BKZGlamrap: sam się dobrowolnie nagrał, z czym jełop ma problem xD',
#   [],
#   '2025-03-01 18:17:38'],
#  [279922997,
#   'vulcanitu',
#   '@BKZGlamrap: czyżby wstydził się swoich słów? ( ͡° ͜ʖ ͡°)',
#   [],
#   '2025-03-01 18:17:38'],
#  [279923521,
#   'Neofuranina',
#   '@ShiroUmizake https://youtube.com/shorts/uKutDFMQPbI',
#   [],
#   '2025-03-01 18:17:38'],
#  [279925595,
#   'Nicolaus_Steno1',
#   '@BKZGlamrap: a za co?',
#   [],
#   '2025-03-01 18:17:38'],
#  [279925671,
#   '006mika',
#   '@BKZGlamrap: jak nie chcesz zasięgów to nie kasuj...',
#   [],
#   '2025-03-01 18:17:38'],
#  [279926741,
#   'json-derollo',
#   '@BKZGlamrap: (⌐ ͡■ ͜ʖ ͡■)',
#   [],
#   '2025-03-01 18:17:38'],
#  [279927079,
#   'BKZGlamrap',
#   '@json-derollo: ale piękna defekacja i zasób słownictwa, niewiele różniąca się od Seby XD.\n\n @006mika jak najbardziej nie, to nie mój kanał',
#   [],
#   '2025-03-01 18:17:38'],
#  [279927167,
#   'Protectorx',
#   '@json-derollo: działu prawnegoxDD Zgłoszone na prokuraturexDDD Co za debilxD',
#   [],
#   '2025-03-01 18:17:38'],
#  [279928561,
#   'maz00rskie_mleko',
#   '@BKZGlamrap do dziaky prawnego hahahaha o luujuu',
#   [],
#   '2025-03-01 18:17:38'],
#  [279929805,
#   'Podstarzaly_Mandalorianin',
#   '@BKZGlamrap: halo! Pomlicja proszę przyjechać na jutjuba ( ͡° ͜ʖ ͡°)',
#   [],
#   '2025-03-01 18:17:38'],
#  [279930289,
#   'Technick20',
#   '@BKZGlamrap: nic się nie zmieniło i dalej stosuje podobne metody straszenia pozwami. Swego czasu jak był w GC to stosował ten sam schemat. Nie pamiętam tylko czy robił to pod filmem tych dwóch lasek, czy brał udział w nalocie piramidziarzy na telegramową grupę. Paruwo z kampera pogódź się z tym, że w społeczności będziesz gościem od mentalnego loda XD',
#   [],
#   '2025-03-01 18:17:38'],
#  [279931401,
#   'sieporobilo',
#   '@BKZGlamrap: ktoś czyści komenty pod tym filmem',
#   [],
#   '2025-03-01 18:17:38'],
#  [279931517,
#   'BKZGlamrap',
#   '@sieporobilo: może autor usunął pajaca, trochę szkoda, bo to jest kompromitacja Gmachcela ¯\\(ツ)/¯',
#   [],
#   '2025-03-01 18:17:38'],
#  [279931649,
#   'sieporobilo',
#   '@BKZGlamrap: jego drugie imię to kompromitacja',
#   [],
#   '2025-03-01 18:17:38'],
#  [80373267,
#   'John_Edgar_Hoover',
#   '#awanturaokase \nPrezes wygląda i mówi trochę jak #sebcel',
#   ['awanturaokase', 'sebcel'],
#   '2025-03-01 17:39:38'],
#  [80372507,
#   'BKZGlamrap',
#   'Tak wygląda człowiek sukcesu, osoba, której udało się złamać schemat jak najbardziej tak ( ͡°( ͡° ͜ʖ( ͡° ͜ʖ ͡°)ʖ ͡°) ͡°)\n\n#sebcel #frajerzyzmlm #heheszki #pdk #riway',
#   ['sebcel', 'frajerzyzmlm', 'heheszki', 'pdk', 'riway'],
#   '2025-03-01 16:39:45'],
#  [279919739,
#   'Nicolaus_Steno1',
#   '@BKZGlamrap: a czemu nie ma zębów?',
#   [],
#   '2025-03-01 16:39:45'],
#  [279920007,
#   'Troojan',
#   'A wy bambusy co, dalej na etacie',
#   [],
#   '2025-03-01 16:39:45'],
#  [279920275,
#   'zacieklykomentator',
#   '@BKZGlamrap co ten Peja...',
#   [],
#   '2025-03-01 16:39:45'],
#  [279920643,
#   'entgegen',
#   '@Nicolaus_Steno1 bo wypadły. Po prostu. Rozumiesz?',
#   [],
#   '2025-03-01 16:39:45'],
#  [279922305,
#   '006mika',
#   '@BKZGlamrap: człowiek który nie wstydzi się swojego homoseksualizmu',
#   [],
#   '2025-03-01 16:39:45'],
#  [279929133,
#   'Madass',
#   '@BKZGlamrap  \n\nWSPÓŁPRACA',
#   [],
#   '2025-03-01 16:39:45'],
#  [279930649,
#   'adriankrasowicz',
#   '@Nicolaus_Steno1: Przecież ma i to co najmniej z 20 sztuk!',
#   [],
#   '2025-03-01 16:39:45'],
#  [80372161,
#   'BrightBeamBuddha',
#   '#sebcel \nA ty schorowany etatowcu dalej bedziesz gadal, ze sie nie da? "Ojezu nie da sie jestem taki schorowany! Nie rzuce pracy bo musze pracowac na leki!" \n\n300$ za 60 pigulek,\n1-2 dziennie \nCzas terapi 3-6 miesiace',
#   ['sebcel'],
#   '2025-03-01 16:02:59'],
#  [279920439,
#   'bb89',
#   '@BrightBeamBuddha ciekawe czy sebcel zacznie to wprost reklamowac',
#   [],
#   '2025-03-01 16:02:59'],
#  [279931075,
#   'czlowiekbozy',
#   '@BrightBeamBuddha: 300 dolców? To jakaś starsza edycja, nowa kosztuje około 4000zł za paczkę ( ͡° ͜ʖ ͡°) a pełna kuracja przeciw nowotworowi na tych suplach 10-12 tysięcy złotych miesięcznie',
#   [],
#   '2025-03-01 16:02:59'],
#  [80371953,
#   'moet',
#   'czas na odwiedziny sanktuarium oszołomów \ntrzeba sobie to przemyśleć i podziękować mentorowi\n#sebcel',
#   ['sebcel'],
#   '2025-03-01 15:38:42'],
#  [279917075, 'moet', 'więcej info po 16:00', [], '2025-03-01 15:38:42'],
#  [279917327,
#   '006mika',
#   '@moet: pozdrów Huberta 👋 od bambusów którym zryło banie ...',
#   [],
#   '2025-03-01 15:38:42'],
#  [80370919,
#   'BKZGlamrap',
#   'Reupload jak najbardziej tak zrzuconej wartości ( ͡°( ͡° ͜ʖ( ͡° ͜ʖ ͡°)ʖ ͡°) ͡°). Cała prawda o #mentorzy\n\n!@kakaowy_chlebicek się słucha rad Nixona, co za bandzwoł...\n\n#sebcel #cieplymentor #cieplymentor2 #frajerzyzmlm #gorcel #izaadamczyk #izadamczyk #nixon #nixontopala #gmachcel',
#   ['mentorzy',
#    'sebcel',
#    'cieplymentor',
#    'cieplymentor2',
#    'frajerzyzmlm',
#    'gorcel',
#    'izaadamczyk',
#    'izadamczyk',
#    'nixon',
#    'nixontopala',
#    'gmachcel'],
#   '2025-03-01 14:10:06'],
#  [279914293,
#   'kakaowy_chlebicek',
#   '@BKZGlamrap: muszę przemyśleć to sobie i zainwestować zamiast w złoto to w dolary tak?',
#   [],
#   '2025-03-01 14:10:06'],
#  [279917383,
#   '006mika',
#   '@kakaowy_chlebicek: dolary to kajdany teraz thermomixy są w cenie...na twoim miejscu kupiłbym starego thermomixa i zrobił na nim flipa',
#   [],
#   '2025-03-01 14:10:06'],
#  [80370663, 'moet', 'DM TULIPAN\n#sebcel', ['sebcel'], '2025-03-01 13:45:54'],
#  [80370381,
#   'kamil_kamil12345K',
#   'NOWA GERIATYCZNA NAZWA PRODUKTU WCHODZI NA RYNEK WSCHODNI I ZACHODNI, JAK I RÓWNIEŻ NA PÓŁNOC I POŁUDNIE:\n\n,,OWCA SYTA I WILK CAŁY,,\n\n¯\\(ツ)/¯\n\nJak się Wam podoba ten ,,przemyśł to sobie,,\n\n#sebcel',
#   ['sebcel'],
#   '2025-03-01 13:20:37'],
#  [80369799,
#   'Kalwi',
#   'Współpraca 👇🔥\n\n#sebcel',
#   ['sebcel'],
#   '2025-03-01 12:30:55'],
#  [279910431,
#   'levzor',
#   '@Kalwi: napisz pod spodem "CHCĘ NA 200%"',
#   [],
#   '2025-03-01 12:30:55'],
#  [279911319, '006mika', '@Kalwi: SZKLARNIA', [], '2025-03-01 12:30:55'],
#  [279916325,
#   'Madass',
#   '@Kalwi  jedź do Budapesztu i powołaj się na mnie pierwszej napotkanej osobie, dalej już będą wiedzieli o co chodzi',
#   [],
#   '2025-03-01 12:30:55']]

# %%
wpisy = [f"Treść: {tresc[2]} data: {tresc[4]}" for tresc in wpisy]

# %%
sys_instruct = """
Jesteś analitykiem trendów na portalu społecznościowym. Twoim zadaniem jest analizować posty i komentarze użytkowników, aby wykryć najważniejsze trendy związane z danym tagiem (społecznością).

    Oto jak masz to zrobić:
    1. Analizuj treści postów i komentarzy, aby zidentyfikować powtarzające się tematy, słowa kluczowe i tagi.
    2. Jeśli w danych nie ma wyraźnych trendów, zwróć odpowiedź: "Brak trendów".
    3. Nie wymyślaj własnych tematów – opieraj się wyłącznie na dostarczonych danych.
    4. Każdy wpis lub komentarz ma format: "Początek: [treść] :Koniec". Znak "#" przed tekstem oznacza tag.

    Przykład:
    - Jeśli w danych często pojawia się tag "#rpa" i tematy związane z polityką, zwróć odpowiedź: "Główny trend: Dyskusje na temat polityki w RPA (#rpa)".
    - Jeśli w danych nie ma powtarzających się tematów, zwróć odpowiedź: "Brak trendów".

    Zwróc tylko 3 najbardziej poruszane tematy w formie zwięzłego podsumowania.
    1. Temat Jakiś data trwania: 23.02.2024 - 24.02.2024
    2. Temat inny data trwania: 22.02.2024 - 24.02.2024
"""

text = ""
for tresc in wpisy:
    text += "Poczatek:" + tresc + ":Koniec"

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=text, # Przekazanie listy jako danych wejściowych
    config=types.GenerateContentConfig(
        max_output_tokens=500,  # Maksymalna liczba tokenów w odpowiedzi
        temperature=0.1,  # Kontrola kreatywności (niska wartość = bardziej deterministyczne odpowiedzi)
        system_instruction=sys_instruct  # Instrukcje systemowe
    )
)


print(response.text)
# Out:
# 1.  **Nieobecność Seby na evencie w Budapeszcie** data trwania: 01.03.2025 - 02.03.2025 - Użytkownicy dyskutują, czy Seba rzeczywiście pojechał na event do Budapesztu, a jeśli nie, to dlaczego.
# 2.  **Krytyka Gmachcela i jego metod** data trwania: 01.03.2025 - 01.03.2025 - Pojawiają się komentarze na temat zachowania Gmachcela, w tym usuwanie komentarzy i groźby działem prawnym.
# 3.  **Promocja produktów i suplementów** data trwania: 01.03.2025 - 01.03.2025 - Dyskutowane są koszty i potencjalna promocja suplementów przez Sebcella.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 client.model("gemini-pro")
#
# NameError: name 'client' is not defined
