# %%
from wykop import WykopAPI
import time


api = WykopAPI("w55988974f3d3194b7dd98c7ab2c6765c2", "05f093e009943e9e9b911f2a8a9f1a00")
api.authenticate()
# Out:
# 2025-02-24 21:40:22.059 | DEBUG    | wykop.wykop_api:authenticate:42 - Authenticated successfully.
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VybmFtZSI6Inc1NTk4ODk3NGYzZDMxOTRiN2RkOThjN2FiMmM2NzY1YzIiLCJ1c2VyLWlwIjoiMTMzNzU3MTY3NyIsInJvbGVzIjpbIlJPTEVfQVBQIl0sImFwcC1rZXkiOiJ3NTU5ODg5NzRmM2QzMTk0YjdkZDk4YzdhYjJjNjc2NWMyIiwiZXhwIjoxNzQwNTE2MDI1fQ.Xv6BPPJ75VI1uyE2loBH4lkbK6nbzNX4f1jbp1YIme4'

# %%
entries = api.make_request(f"tags/przegryw/stream?page=1&limit=25&sort=all&type=entry&multimedia=false'")
entries
# Out:
# 2025-02-24 21:40:49.910 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/tags/przegryw/stream?page=1&limit=25&sort=all&type=entry&multimedia=false'
# {'data': [{'id': 80311785,
#    'slug': 'caly-wykop-czeka-na-pojedynek-szachowy-miedzy-mna-',
#    'author': {'username': 'SonGoku92',
#     'gender': 'm',
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c0834752/7961f60fa963d70616c192fa51a43f9aa379cfa27a53d38001137a03796a3570.jpg',
#     'status': 'active',
#     'color': 'green',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': True},
#    'device': '',
#    'created_at': '2025-02-24 21:37:56',
#    'voted': 0,
#    'content': 'Cały wykop czeka na pojedynek szachowy miedzy mną a @ProstyHuop , więc kiedy? #przegryw #szachy',
#    'media': {'photo': None, 'embed': None, 'survey': None},
#    'adult': False,
#    'tags': ['przegryw', 'szachy'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 1,
#     'down': 0,
#     'users': [{'username': 'Mandon',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/6b61d5597fe748ce6c15c039119398a85781557c9857adefbb32e74a707d0510.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [], 'count': 0},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311761,
#    'slug': 'takie-cos-zrobilem-na-5-rano-i-jak-sie-podoba-czy-',
#    'author': {'username': 'Zwierz33',
#     'gender': 'm',
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c0834752/fca5face8399750d5279af8d3d6110cc607b972cca030256f6a9623b5ec956f3.jpg',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': False},
#    'device': '',
#    'created_at': '2025-02-24 21:36:26',
#    'voted': 0,
#    'content': 'Takie coś zrobiłem na 5 rano. I jak się podoba ? Czy lipa ? \n\n#przegryw',
#    'media': {'photo': {'key': 'eEAxy1LNWqpZQbw4d9MBkKDLnPrpK80YnzDOP3am627JRglXVv',
#      'label': 'GoWork2',
#      'mime_type': 'image/jpeg',
#      'url': 'https://wykop.pl/cdn/c3201142/557a958b08c8f9e9d50f6e41b81e236a80c330ec999b1632d046a103b931f284.jpg?author=Zwierz33&auth=41f1bf8baf6da6b457888e66a4f12841',
#      'size': 786490,
#      'width': 920,
#      'height': 921},
#     'embed': None,
#     'survey': None},
#    'adult': False,
#    'tags': ['przegryw'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 3,
#     'down': 0,
#     'users': [{'username': 'inkill',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c3397992/inkill_534O8kb6Wt.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': False},
#      {'username': 'szyderczy_szczur',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/ac5172c474ab11cb0160bad73194e018eadee86e8349ae9c127dedbb415f437b.png',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': 3028, 'trend': 1},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': False},
#      {'username': 'kowalski-codamy',
#       'gender': 'm',
#       'company': False,
#       'avatar': '',
#       'status': 'active',
#       'color': 'green',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [{'id': 279728947,
#       'slug': 'zwierz33-lipa',
#       'author': {'username': 'SonGoku92',
#        'gender': 'm',
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c0834752/7961f60fa963d70616c192fa51a43f9aa379cfa27a53d38001137a03796a3570.jpg',
#        'status': 'active',
#        'color': 'green',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': True},
#       'device': 'Wykop',
#       'created_at': '2025-02-24 21:38:12',
#       'voted': 0,
#       'content': '@Zwierz33: lipa',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311761,
#        'slug': 'takie-cos-zrobilem-na-5-rano-i-jak-sie-podoba-czy-',
#        'author': {'username': 'Zwierz33',
#         'gender': 'm',
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/fca5face8399750d5279af8d3d6110cc607b972cca030256f6a9623b5ec956f3.jpg',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': False},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 1,
#        'down': 0,
#        'users': [{'username': 'Zwierz33',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/fca5face8399750d5279af8d3d6110cc607b972cca030256f6a9623b5ec956f3.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': False}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True},
#      {'id': 279729039,
#       'slug': 'zwierz33-a-tego-nie-wiem-brzydko-wyglada',
#       'author': {'username': 'SonGoku92',
#        'gender': 'm',
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c0834752/7961f60fa963d70616c192fa51a43f9aa379cfa27a53d38001137a03796a3570.jpg',
#        'status': 'active',
#        'color': 'green',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': True},
#       'device': 'Wykop',
#       'created_at': '2025-02-24 21:40:33',
#       'voted': 0,
#       'content': '@Zwierz33: a tego nie wiem, brzydko wyglada',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311761,
#        'slug': 'takie-cos-zrobilem-na-5-rano-i-jak-sie-podoba-czy-',
#        'author': {'username': 'Zwierz33',
#         'gender': 'm',
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/fca5face8399750d5279af8d3d6110cc607b972cca030256f6a9623b5ec956f3.jpg',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': False},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 0, 'down': 0, 'users': []},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True}],
#     'count': 3},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311755,
#    'slug': 'w-ogole-dinek-to-strasznie-zalosny-nick-brzmi-jak-',
#    'author': {'username': 'Dinek30',
#     'gender': 'm',
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c0834752/35b40fc53694809cf05f45a3421ae5f85217376d862baf6842b09158e97539e0.png',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': False},
#    'device': '',
#    'created_at': '2025-02-24 21:36:10',
#    'voted': 0,
#    'content': 'W ogóle Dinek to strasznie żałosny nick, brzmi jak dla 6 letniego dziecka. \n#przegryw',
#    'media': {'photo': None, 'embed': None, 'survey': None},
#    'adult': False,
#    'tags': ['przegryw'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 9,
#     'down': 0,
#     'users': [{'username': 'Mandon',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/6b61d5597fe748ce6c15c039119398a85781557c9857adefbb32e74a707d0510.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'PawelW124',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/3d42b433eb4314681edc40cc46273a06662fa74a16315c93409356e60314d8a7.png',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': 1792, 'trend': 1},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': False},
#      {'username': 'hibiskus_mi_umieraa',
#       'gender': None,
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/9d74ad37b8ebd8de471b04bbd2a07b0061d78aabfdec2aaa421e9a24e9c959ad.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'tomasz_mazur',
#       'gender': None,
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/744ef55cf35c5ddcc28ebfaf1ace501d4a76b237573ed5c30b63fdcc5836ba5e.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'qew12',
#       'gender': None,
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/b1e733ed9672bff4693c25332fdbc8f57cfa2ac44048dcd0c1fe8ef6c5337d0f.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [{'id': 279728889,
#       'slug': 'dinek30-mi-sie-podoba',
#       'author': {'username': 'hibiskus_mi_umieraa',
#        'gender': None,
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c0834752/9d74ad37b8ebd8de471b04bbd2a07b0061d78aabfdec2aaa421e9a24e9c959ad.jpg',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': True},
#       'device': 'Android',
#       'created_at': '2025-02-24 21:36:55',
#       'voted': 0,
#       'content': '@Dinek30 Mi się podoba.',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311755,
#        'slug': 'w-ogole-dinek-to-strasznie-zalosny-nick-brzmi-jak-',
#        'author': {'username': 'Dinek30',
#         'gender': 'm',
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/35b40fc53694809cf05f45a3421ae5f85217376d862baf6842b09158e97539e0.png',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': False},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 1,
#        'down': 0,
#        'users': [{'username': 'remlezar',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True},
#      {'id': 279728893,
#       'slug': 'dinek30-avatar-nie-pomaga-xd',
#       'author': {'username': 'tomasz_mazur',
#        'gender': None,
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c0834752/744ef55cf35c5ddcc28ebfaf1ace501d4a76b237573ed5c30b63fdcc5836ba5e.jpg',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': True},
#       'device': 'Wykop',
#       'created_at': '2025-02-24 21:36:59',
#       'voted': 0,
#       'content': '@Dinek30: avatar nie pomaga xd',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311755,
#        'slug': 'w-ogole-dinek-to-strasznie-zalosny-nick-brzmi-jak-',
#        'author': {'username': 'Dinek30',
#         'gender': 'm',
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/35b40fc53694809cf05f45a3421ae5f85217376d862baf6842b09158e97539e0.png',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': False},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 1,
#        'down': 0,
#        'users': [{'username': 'what-up',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/3770f759e02d5c1e0cac73a7b5f98f7294910ec5e8ce922a2c2bf959806e8e70.webp',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True}],
#     'count': 4},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311751,
#    'slug': 'ok-oski-przegryw',
#    'author': {'username': 'NaPryczyHuopSieByczy',
#     'gender': None,
#     'company': False,
#     'avatar': '',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': True},
#    'device': '',
#    'created_at': '2025-02-24 21:35:31',
#    'voted': 0,
#    'content': 'Ok oski \n#przegryw',
#    'media': {'photo': None, 'embed': None, 'survey': None},
#    'adult': False,
#    'tags': ['przegryw'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 3,
#     'down': 0,
#     'users': [{'username': 'Mandon',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/6b61d5597fe748ce6c15c039119398a85781557c9857adefbb32e74a707d0510.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'remlezar',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'what-up',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/3770f759e02d5c1e0cac73a7b5f98f7294910ec5e8ce922a2c2bf959806e8e70.webp',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [], 'count': 0},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311705,
#    'slug': 'przegryw-ladnapani-taka-by-wystarczyla-dla-jego-la',
#    'author': {'username': 'remlezar',
#     'gender': 'm',
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': True},
#    'device': '',
#    'created_at': '2025-02-24 21:31:26',
#    'voted': 0,
#    'content': '#przegryw #ladnapani\n\nTaka by wystarczyła dla jego, ładne oczki, uśmiech',
#    'media': {'photo': {'key': 'PWXnEbQrvegqJkYZLO8p0KJgnAZwjRm79ABdaVN2Dl3M4x6y5z',
#      'label': '1000088595',
#      'mime_type': 'image/jpeg',
#      'url': 'https://wykop.pl/cdn/c3201142/9aec5acdbfc9289007edd323fcc4ad0377fdd51ec5abf89eb0f3d3c18146b78c.jpg',
#      'size': 372255,
#      'width': 1250,
#      'height': 1666},
#     'embed': None,
#     'survey': None},
#    'adult': False,
#    'tags': ['przegryw', 'ladnapani'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 5,
#     'down': 0,
#     'users': [{'username': 'Polishdoomer02',
#       'gender': None,
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/772e7e07aa63b95681ec71a69f2f18b33c71588817195c5c096816558eae1143.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'Mandon',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/6b61d5597fe748ce6c15c039119398a85781557c9857adefbb32e74a707d0510.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'mirekzlasu',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/ee396c8e45be878093a87d5e18ff427269f86ef4e394bc5b45d52b7a73eaef5a.png',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'NaPryczyHuopSieByczy',
#       'gender': None,
#       'company': False,
#       'avatar': '',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'what-up',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/3770f759e02d5c1e0cac73a7b5f98f7294910ec5e8ce922a2c2bf959806e8e70.webp',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [{'id': 279728685,
#       'slug': 'remlezar-bylaby-dla-chlopa',
#       'author': {'username': 'Polishdoomer02',
#        'gender': None,
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c0834752/772e7e07aa63b95681ec71a69f2f18b33c71588817195c5c096816558eae1143.jpg',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': True},
#       'device': 'Android',
#       'created_at': '2025-02-24 21:31:49',
#       'voted': 0,
#       'content': '@remlezar byłaby dla chłopa',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311705,
#        'slug': 'przegryw-ladnapani-taka-by-wystarczyla-dla-jego-la',
#        'author': {'username': 'remlezar',
#         'gender': 'm',
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': True},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 2,
#        'down': 0,
#        'users': [{'username': 'remlezar',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True},
#         {'username': 'mirekzlasu',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/ee396c8e45be878093a87d5e18ff427269f86ef4e394bc5b45d52b7a73eaef5a.png',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True},
#      {'id': 279728841,
#       'slug': 'remlezar-ok',
#       'author': {'username': 'Dzieci_z_Choroszczy',
#        'gender': 'm',
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c3397992/Dzieci_z_Choroszczy_ilYMkMUfDb.jpg',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': True},
#       'device': 'Android',
#       'created_at': '2025-02-24 21:35:23',
#       'voted': 0,
#       'content': '@remlezar ok',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311705,
#        'slug': 'przegryw-ladnapani-taka-by-wystarczyla-dla-jego-la',
#        'author': {'username': 'remlezar',
#         'gender': 'm',
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': True},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 1,
#        'down': 0,
#        'users': [{'username': 'remlezar',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True}],
#     'count': 2},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311689,
#    'slug': 'jaka-przewozka-no-klasa-w-polsce-nam-takiego-czego',
#    'author': {'username': 'pomelobezkaca2',
#     'gender': 'm',
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c0834752/4816d668a23b2a3bd4473e6adcf8978a7db301212a1848fa1dda4e74a8f705e5.png',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': True},
#    'device': '',
#    'created_at': '2025-02-24 21:30:11',
#    'voted': 0,
#    'content': 'jaka przewozka, no klasa, w polsce nam takiego czegos potrzeba w rapie.\n\n#przegryw',
#    'media': {'photo': None,
#     'embed': {'key': 'AXvwaN4mJeDVMWOZkzgYBokqkVgdjyn0916Rx5b7dq2lpPL8Qr',
#      'type': 'youtube',
#      'thumbnail': 'https://wykop.pl/cdn/c3201142/0b5b47c9ab56f948a1fe8511c11767e4eb6dd966698ed5fe785ac2f9be8775ca.jpg',
#      'url': 'https://youtu.be/c-FSzuGmk3k?si=SgEe2A5Z6fPjUsrE',
#      'age_category': 'all',
#      'video_metadata': None,
#      'commercial': False},
#     'survey': None},
#    'adult': False,
#    'tags': ['przegryw'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 4,
#     'down': 0,
#     'users': [{'username': 'rasTt4',
#       'gender': None,
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/ff94d7b8da963c7963adc8bc54644e6cea77bd9ca04307357beb647c853ed4cc.webp',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'Mandon',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/6b61d5597fe748ce6c15c039119398a85781557c9857adefbb32e74a707d0510.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'mirekzlasu',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/ee396c8e45be878093a87d5e18ff427269f86ef4e394bc5b45d52b7a73eaef5a.png',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'what-up',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/3770f759e02d5c1e0cac73a7b5f98f7294910ec5e8ce922a2c2bf959806e8e70.webp',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [], 'count': 0},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311681,
#    'slug': 'ide-spac-przegryw',
#    'author': {'username': 'BekaZTypaLOL',
#     'gender': 'm',
#     'company': False,
#     'avatar': '',
#     'status': 'active',
#     'color': 'green',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': True},
#    'device': '',
#    'created_at': '2025-02-24 21:29:04',
#    'voted': 0,
#    'content': 'Idę spać.\n\n#przegryw',
#    'media': {'photo': None, 'embed': None, 'survey': None},
#    'adult': False,
#    'tags': ['przegryw'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 6,
#     'down': 0,
#     'users': [{'username': 'kowalski-codamy',
#       'gender': 'm',
#       'company': False,
#       'avatar': '',
#       'status': 'active',
#       'color': 'green',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'Polishdoomer02',
#       'gender': None,
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/772e7e07aa63b95681ec71a69f2f18b33c71588817195c5c096816558eae1143.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'Mandon',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/6b61d5597fe748ce6c15c039119398a85781557c9857adefbb32e74a707d0510.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'remlezar',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'kartofel322',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/421ba9a1a856bd9d23bc9c65a6f70bb8586a36d386fe7f92d219e6bb3e4e67f3.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': False}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [{'id': 279728613,
#       'slug': 'bekaztypalol-smiechu-warte',
#       'author': {'username': 'what-up',
#        'gender': 'm',
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c0834752/3770f759e02d5c1e0cac73a7b5f98f7294910ec5e8ce922a2c2bf959806e8e70.webp',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': True},
#       'device': 'Wykop',
#       'created_at': '2025-02-24 21:30:10',
#       'voted': 0,
#       'content': '@BekaZTypaLOL: śmiechu warte',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311681,
#        'slug': 'ide-spac-przegryw',
#        'author': {'username': 'BekaZTypaLOL',
#         'gender': 'm',
#         'company': False,
#         'avatar': '',
#         'status': 'active',
#         'color': 'green',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': True},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 3,
#        'down': 0,
#        'users': [{'username': 'BekaZTypaLOL',
#          'gender': 'm',
#          'company': False,
#          'avatar': '',
#          'status': 'active',
#          'color': 'green',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True},
#         {'username': 'Polishdoomer02',
#          'gender': None,
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/772e7e07aa63b95681ec71a69f2f18b33c71588817195c5c096816558eae1143.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True},
#         {'username': 'remlezar',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True},
#      {'id': 279728631,
#       'slug': 'bekaztypalol-to-spij-slodko-kochanie',
#       'author': {'username': 'Dzieci_z_Choroszczy',
#        'gender': 'm',
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c3397992/Dzieci_z_Choroszczy_ilYMkMUfDb.jpg',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': True},
#       'device': 'Android',
#       'created_at': '2025-02-24 21:30:42',
#       'voted': 0,
#       'content': '@BekaZTypaLOL To śpij słodko kochanie 💕',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311681,
#        'slug': 'ide-spac-przegryw',
#        'author': {'username': 'BekaZTypaLOL',
#         'gender': 'm',
#         'company': False,
#         'avatar': '',
#         'status': 'active',
#         'color': 'green',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': True},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 4,
#        'down': 0,
#        'users': [{'username': 'Polishdoomer02',
#          'gender': None,
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/772e7e07aa63b95681ec71a69f2f18b33c71588817195c5c096816558eae1143.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True},
#         {'username': 'BekaZTypaLOL',
#          'gender': 'm',
#          'company': False,
#          'avatar': '',
#          'status': 'active',
#          'color': 'green',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True},
#         {'username': 'remlezar',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/2399c2888d4c5ad4cf6c5fb23bdad24cb6696c5132dc98e338a600a1fe57561f.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True},
#         {'username': 'Van-der-Ledre',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c3397992/Van-der-Ledre_DVsiYimVww.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': False}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True}],
#     'count': 5},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311655,
#    'slug': 'przegryw-czy-jak-mam-jedna-sznurowke-real-a-jedna-',
#    'author': {'username': 'rasTt4',
#     'gender': None,
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c0834752/ff94d7b8da963c7963adc8bc54644e6cea77bd9ca04307357beb647c853ed4cc.webp',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': True},
#    'device': '',
#    'created_at': '2025-02-24 21:27:51',
#    'voted': 0,
#    'content': '#przegryw czy jak mam jedna sznurówke real a jedna fake z aliexpress to myslicie ze ludzie sie kapna ze cos nie tak? #buty  #nike #s--s #rozowepaski #Niebieskiepaski #P0lka',
#    'media': {'photo': None,
#     'embed': None,
#     'survey': {'key': 'zg3KE9WkyK2v',
#      'question': 'Ludzie kapną sie ze cos nie tak z sznurówka',
#      'answers': [{'text': 'tak', 'id': 1, 'count': 5, 'voted': 0},
#       {'text': 'nie', 'id': 2, 'count': 8, 'voted': 0}],
#      'voted': 0,
#      'count': 13,
#      'editable': False,
#      'deletable': False,
#      'actions': {'create': False,
#       'update': False,
#       'delete': False,
#       'vote': False}}},
#    'adult': False,
#    'tags': ['przegryw',
#     'buty',
#     'nike',
#     'seks',
#     'rozowepaski',
#     'niebieskiepaski',
#     'p0lka'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 1,
#     'down': 0,
#     'users': [{'username': 'Mandon',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/6b61d5597fe748ce6c15c039119398a85781557c9857adefbb32e74a707d0510.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [{'id': 279728939,
#       'slug': 'rastt4-jakby-ktos-cos-gadal-to-powiedz-ze-mizogin-i-incel',
#       'author': {'username': 'LostHoldenCaulfield',
#        'gender': 'm',
#        'company': False,
#        'avatar': '',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': False},
#       'device': 'Wykop',
#       'created_at': '2025-02-24 21:38:05',
#       'voted': 0,
#       'content': '@rasTt4: Jakby ktoś coś gadał to powiedz, że mizogin i incel.',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311655,
#        'slug': 'przegryw-czy-jak-mam-jedna-sznurowke-real-a-jedna-',
#        'author': {'username': 'rasTt4',
#         'gender': None,
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/ff94d7b8da963c7963adc8bc54644e6cea77bd9ca04307357beb647c853ed4cc.webp',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': True},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 1,
#        'down': 0,
#        'users': [{'username': 'rasTt4',
#          'gender': None,
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/ff94d7b8da963c7963adc8bc54644e6cea77bd9ca04307357beb647c853ed4cc.webp',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True},
#      {'id': 279728967,
#       'slug': 'lostholdencaulfield-ze-fake-buty-z-hin-za-darmo-xd-a-ja-dalem-4-stuwy',
#       'author': {'username': 'rasTt4',
#        'gender': None,
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c0834752/ff94d7b8da963c7963adc8bc54644e6cea77bd9ca04307357beb647c853ed4cc.webp',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': True},
#       'device': 'Wykop',
#       'created_at': '2025-02-24 21:38:44',
#       'voted': 0,
#       'content': '@LostHoldenCaulfield: ze fake buty z hin za darmo xd a ja dalem 4 stuwy',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311655,
#        'slug': 'przegryw-czy-jak-mam-jedna-sznurowke-real-a-jedna-',
#        'author': {'username': 'rasTt4',
#         'gender': None,
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/ff94d7b8da963c7963adc8bc54644e6cea77bd9ca04307357beb647c853ed4cc.webp',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': True},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 0, 'down': 0, 'users': []},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True}],
#     'count': 5},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311647,
#    'slug': 'miszeleniano-tv-xdddddd-przegryw-kononowicz-patost',
#    'author': {'username': 'RadosnaKloaka',
#     'gender': 'm',
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c0834752/e4dcb8d213f647d3d4dd9a663fba85b1fd16f85f0e5722e3c4c22f0f8be446ef.jpg',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': True},
#    'device': '',
#    'created_at': '2025-02-24 21:27:33',
#    'voted': 0,
#    'content': 'Miszeleniano TV XDDDDDD\n\n#przegryw #kononowicz #patostreamy',
#    'media': {'photo': None,
#     'embed': {'key': 'ZPdqXvY64OarL0yblMgJ1oYAEl5yoB9zNkAD5mWpwRx7eQV28n',
# ...
#      'mime_type': 'image/jpeg',
#      'url': 'https://wykop.pl/cdn/c3201142/3e9f9165e2b379b677037070301b7a747fa7d9c0cb9752eaddde2f8e72a45452.jpg?author=Zwierz33&auth=41f1bf8baf6da6b457888e66a4f12841',
#      'size': 96424,
#      'width': 828,
#      'height': 536},
#     'embed': {'key': 'XWgv4DMRam7LyPqpxAO2zo9zZdzeK9QBwEVYdNr1l3086bnkJZ',
#      'type': 'streamable',
#      'thumbnail': 'https://wykop.pl/cdn/c3201142/5b4f5d26a46342aa9b290cab4108099223c76cfe55852a00161b5f65742651fe.jpg?author=Zwierz33&auth=41f1bf8baf6da6b457888e66a4f12841',
#      'url': 'https://streamable.com/bearjg',
#      'age_category': 'all',
#      'video_metadata': None,
#      'commercial': False},
#     'survey': None},
#    'adult': False,
#    'tags': ['przegryw'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 3,
#     'down': 0,
#     'users': [{'username': 'armin-van-kutonger',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/3a3d8732de84f5899118ffecee17dcb6ee61b7ea8b5a96b3239ea50531f5ca1c.png',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'Van-der-Ledre',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c3397992/Van-der-Ledre_DVsiYimVww.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': False},
#      {'username': 'kowalski-codamy',
#       'gender': 'm',
#       'company': False,
#       'avatar': '',
#       'status': 'active',
#       'color': 'green',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [], 'count': 0},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311459,
#    'slug': 'i-to-jest-faza-dziekuje-jeszcze-raz-tej-osobie-skr',
#    'author': {'username': 'RadosnaKloaka',
#     'gender': 'm',
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c0834752/e4dcb8d213f647d3d4dd9a663fba85b1fd16f85f0e5722e3c4c22f0f8be446ef.jpg',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': True},
#    'device': '',
#    'created_at': '2025-02-24 21:12:33',
#    'voted': 0,
#    'content': 'I to jest faza! Dziękuję jeszcze raz tej osobie! \n\nSkrzypcano 2017-2018, ehhh. Jakie to były piękne lata!\n\n#przegryw #kononowicz #patostreamy',
#    'media': {'photo': None,
#     'embed': {'key': '8BAYbzlEea93RL2VrMy6dj1EmBEbjXvmpq05n4DO7ZNxgJwQkP',
#      'type': 'youtube',
#      'thumbnail': 'https://wykop.pl/cdn/c3201142/741887243e47fae30df29ae92dff6977bc96ba824abb86a0accdf8e7207c107f.jpg',
#      'url': 'https://www.youtube.com/watch?v=yzKFEZKwg50',
#      'age_category': 'all',
#      'video_metadata': None,
#      'commercial': False},
#     'survey': None},
#    'adult': False,
#    'tags': ['przegryw', 'kononowicz', 'patostreamy'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 9,
#     'down': 0,
#     'users': [{'username': 'kowalski-codamy',
#       'gender': 'm',
#       'company': False,
#       'avatar': '',
#       'status': 'active',
#       'color': 'green',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'Mandon',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/6b61d5597fe748ce6c15c039119398a85781557c9857adefbb32e74a707d0510.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'Tabasco666',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/943da5cb8f1d274272f8460d079edc6f7ee1b77ca93fb03fc62ed5643cb993df.png',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'alfonsgajowy',
#       'gender': None,
#       'company': False,
#       'avatar': '',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': False},
#      {'username': 'DonTadeo',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c3397992/DonTadeo_X505nhgpkr.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': False}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [{'id': 279728257,
#       'slug': 'radosnakloaka-menel-meloman-podroznik-koneser-surowego-miesa',
#       'author': {'username': 'tralala101',
#        'gender': None,
#        'company': False,
#        'avatar': '',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': None, 'trend': 0},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': False},
#       'device': 'Wykop',
#       'created_at': '2025-02-24 21:21:19',
#       'voted': 0,
#       'content': '@RadosnaKloaka: Menel meloman, podróżnik, koneser surowego mięsa.',
#       'media': {'photo': None,
#        'embed': {'key': 'eEAxy1LNWqpZQbw4d9MBkKDleZk7K80YnzDOP3am627JRglXVv',
#         'type': 'youtube',
#         'thumbnail': 'https://wykop.pl/cdn/c3201142/c14301fee3661ae5ef8a366d11e59edcd5b96da99654bffbab7a01bea8dc7446.jpg?author=tralala101&auth=d03c69a3ee6f9360e62231fa80851c78',
#         'url': 'https://www.youtube.com/watch?v=Px3hmDh2MoQ',
#         'age_category': 'all',
#         'video_metadata': None,
#         'commercial': False}},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311459,
#        'slug': 'i-to-jest-faza-dziekuje-jeszcze-raz-tej-osobie-skr',
#        'author': {'username': 'RadosnaKloaka',
#         'gender': 'm',
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/e4dcb8d213f647d3d4dd9a663fba85b1fd16f85f0e5722e3c4c22f0f8be446ef.jpg',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': True},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 3,
#        'down': 0,
#        'users': [{'username': 'RadosnaKloaka',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/e4dcb8d213f647d3d4dd9a663fba85b1fd16f85f0e5722e3c4c22f0f8be446ef.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True},
#         {'username': 'Arizona221',
#          'gender': None,
#          'company': True,
#          'avatar': 'https://wykop.pl/cdn/c0834752/ad58db25d2380b1bdd447f4c4ad45616f8ef209a5fc551e8de4f8750c725a36f.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True},
#         {'username': 'Tabasco666',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/943da5cb8f1d274272f8460d079edc6f7ee1b77ca93fb03fc62ed5643cb993df.png',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True},
#      {'id': 279728335,
#       'slug': 'radosnakloaka-esencja-szkolnej-i-tego-absurdu-piekne-czasy',
#       'author': {'username': 'Scybulko',
#        'gender': 'm',
#        'company': False,
#        'avatar': 'https://wykop.pl/cdn/c0834752/872a5ad4b6fbcb93164e3c52cfbfb177eff90b2cd43aac1171025f40b77922e1.jpg',
#        'status': 'active',
#        'color': 'orange',
#        'verified': False,
#        'rank': {'position': 1560, 'trend': 1},
#        'blacklist': False,
#        'follow': False,
#        'note': False,
#        'online': False},
#       'device': 'Wykop',
#       'created_at': '2025-02-24 21:23:48',
#       'voted': 0,
#       'content': '@RadosnaKloaka: esencja szkolnej i tego absurdu. Piękne czasy.',
#       'media': {'photo': None, 'embed': None},
#       'adult': False,
#       'tags': [],
#       'favourite': False,
#       'parent': {'resource': 'entry',
#        'id': 80311459,
#        'slug': 'i-to-jest-faza-dziekuje-jeszcze-raz-tej-osobie-skr',
#        'author': {'username': 'RadosnaKloaka',
#         'gender': 'm',
#         'company': False,
#         'avatar': 'https://wykop.pl/cdn/c0834752/e4dcb8d213f647d3d4dd9a663fba85b1fd16f85f0e5722e3c4c22f0f8be446ef.jpg',
#         'status': 'active',
#         'color': 'orange',
#         'verified': False,
#         'rank': {'position': None, 'trend': 0},
#         'blacklist': False,
#         'follow': False,
#         'note': False,
#         'online': True},
#        'location': [{'filter': 'oldest', 'page': 1}]},
#       'votes': {'up': 2,
#        'down': 0,
#        'users': [{'username': 'RadosnaKloaka',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/e4dcb8d213f647d3d4dd9a663fba85b1fd16f85f0e5722e3c4c22f0f8be446ef.jpg',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True},
#         {'username': 'Tabasco666',
#          'gender': 'm',
#          'company': False,
#          'avatar': 'https://wykop.pl/cdn/c0834752/943da5cb8f1d274272f8460d079edc6f7ee1b77ca93fb03fc62ed5643cb993df.png',
#          'status': 'active',
#          'color': 'orange',
#          'verified': False,
#          'rank': {'position': None, 'trend': 0},
#          'blacklist': False,
#          'follow': False,
#          'note': False,
#          'online': True}]},
#       'editable': False,
#       'deletable': False,
#       'blacklist': False,
#       'deleted': None,
#       'resource': 'entry_comment',
#       'actions': {'vote_up': False,
#        'vote_down': False,
#        'create': False,
#        'delete': False,
#        'update': False,
#        'report': False,
#        'create_favourite': False,
#        'delete_favourite': False},
#       'archive': False,
#       'family_friendly': True}],
#     'count': 4},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True},
#   {'id': 80311447,
#    'slug': 'chcialem-na-kfc-ponarzekac-ale-sobie-odpuszcze-mog',
#    'author': {'username': 'pomelobezkaca2',
#     'gender': 'm',
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c0834752/4816d668a23b2a3bd4473e6adcf8978a7db301212a1848fa1dda4e74a8f705e5.png',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': True},
#    'device': '',
#    'created_at': '2025-02-24 21:11:27',
#    'voted': 0,
#    'content': 'Chcialem na kfc ponarzekac ale sobie odpuszcze,\n\nmoglbym kiedys cos pochwalic, byc z czegos zadowolonym a nie ciagle krecic nosem, masakra.\n\n#przegryw',
#    'media': {'photo': None, 'embed': None, 'survey': None},
#    'adult': False,
#    'tags': ['przegryw'],
#    'favourite': False,
#    'parent': None,
#    'votes': {'up': 5,
#     'down': 0,
#     'users': [{'username': 'JanNaj358',
#       'gender': None,
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/bca96c49b6a4946bfa47e31e77dee61c5bde4e7bb54ac7c28a60eb6ff11574ec.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'Nieznajomy_U_Bram',
#       'gender': None,
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c3397992/Nieznajomy_U_Bram_NekT3pJbPS.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': False},
#      {'username': 'CiemnoSmutnoZimno',
#       'gender': None,
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/9b129b7f2aa27ff25614f653fb4fc8fea9d16699eb08d01100d842bcbdc7c8a3.png',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'Mandon',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/6b61d5597fe748ce6c15c039119398a85781557c9857adefbb32e74a707d0510.jpg',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True},
#      {'username': 'what-up',
#       'gender': 'm',
#       'company': False,
#       'avatar': 'https://wykop.pl/cdn/c0834752/3770f759e02d5c1e0cac73a7b5f98f7294910ec5e8ce922a2c2bf959806e8e70.webp',
#       'status': 'active',
#       'color': 'orange',
#       'verified': False,
#       'rank': {'position': None, 'trend': 0},
#       'blacklist': False,
#       'follow': False,
#       'note': False,
#       'online': True}]},
#    'editable': False,
#    'deletable': False,
#    'comments': {'items': [], 'count': 0},
#    'resource': 'entry',
#    'actions': {'create': False,
#     'update': False,
#     'delete': False,
#     'vote_up': False,
#     'undo_vote': False,
#     'create_favourite': False,
#     'delete_favourite': False,
#     'report': False,
#     'pin': False,
#     'unpin': False},
#    'archive': False,
#    'observed_discussion': False,
#    'status': 'visible',
#    'tag_pinned_content': False,
#    'pinnable': False,
#    'family_friendly': True}],
#  'pagination': {'per_page': 25, 'total': 10000}}
