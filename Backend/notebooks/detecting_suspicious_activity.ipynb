# %% [markdown]
# # Zbadanie możliwości
# Chce pobrać wpisy i użytkowników i sprawdzić kto publikuje co a potem sprawdzić połączenia

# %%
import handy_functions as hf
import networkx as nx
from wykop import WykopAPI

# %%
posts = hf.get_posts_and_comments("nieruchomosci", 1)
posts
# Out:
# 2025-02-15 22:17:35.839 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/tags/nieruchomosci/stream?page=1&limit=25&sort=all&type=entry&multimedia=false'
# 2025-02-15 22:17:37.338 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80201265/comments?page=1&limit=25
# 2025-02-15 22:17:37.404 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80201265/comments?page=2&limit=25
# 2025-02-15 22:17:38.472 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80201183/comments?page=1&limit=25
# 2025-02-15 22:17:38.539 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80201183/comments?page=2&limit=25
# 2025-02-15 22:17:39.607 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/entries/80200967/comments?page=1&limit=25
# ...

# %%
api = WykopAPI("w55988974f3d3194b7dd98c7ab2c6765c2", "05f093e009943e9e9b911f2a8a9f1a00")
api.authenticate()
# Out:
# 2025-02-15 22:34:07.031 | DEBUG    | wykop.wykop_api:authenticate:42 - Authenticated successfully.
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VybmFtZSI6Inc1NTk4ODk3NGYzZDMxOTRiN2RkOThjN2FiMmM2NzY1YzIiLCJ1c2VyLWlwIjoiMTMzNzUzNDE3OCIsInJvbGVzIjpbIlJPTEVfQVBQIl0sImFwcC1rZXkiOiJ3NTU5ODg5NzRmM2QzMTk0YjdkZDk4YzdhYjJjNjc2NWMyIiwiZXhwIjoxNzM5NzQxNjUwfQ.RjK4JkkcKhdi4VE31Ou82z8HxcfXWTjDxLW-ewlH1B4'

# %%
entries = api.make_request(f"tags/przegryw/stream?page=1&limit=25&sort=all&type=entry&multimedia=false'")
entries = entries['data']
entries
# Out:
# 2025-02-15 22:35:24.322 | DEBUG    | wykop.wykop_api:make_request:64 - Making request to https://wykop.pl/api/v3/tags/przegryw/stream?page=1&limit=25&sort=all&type=entry&multimedia=false'
# [{'id': 80201857,
#   'slug': 'przydaloby-sie-takie-spotkanie-trvcelskie-uczynic-',
#   'author': {'username': 'Van-der-Ledre',
#    'gender': 'm',
#    'company': False,
#    'avatar': 'https://wykop.pl/cdn/c3397992/Van-der-Ledre_DVsiYimVww.jpg',
#    'status': 'active',
#    'color': 'orange',
#    'verified': False,
#    'rank': {'position': None, 'trend': 0},
#    'blacklist': False,
#    'follow': False,
#    'note': False,
#    'online': False},
#   'device': '',
#   'created_at': '2025-02-15 22:34:46',
#   'voted': 0,
#   'content': 'Przydałoby się takie spotkanie trvcelskie uczynić, aczkolwiek to zapewne nierealne z wiadomych przyczyn. \n#przegryw',
#   'media': {'photo': {'key': 'yXz95avQ2mPpEqnVMLlNYKrlbWR8G30DA8rWwOJkB746eRbxgZ',
#     'label': 'IMG_0602',
# ...
